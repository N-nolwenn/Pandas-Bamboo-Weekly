# %% [markdown]
# # BW \#158 University Endowments
# Running a university, and especially a research universiy, is expensive. Student tuition, doesn't even come close to covering the costs. So where does the money come from ?
#
# In the case of research uni, much of it comes in the form of grants, from governments or foundations. But universities often have an endowment, money that has been donated, and invested, with the aim of never actually spending it. Instead the hope is to use the interest, profits and dividends from the endowments as part of the annual budget.
#
# ## Data and six questions
# This week, we'll thus be looking at data about university endowments, based on the data collected by NACUBO, the National Association of College and University Business Officers
#
# ## Challenges
# The learning goals include xcel and csv files, grouping, plotting with plotly, cleaning data and joins.
#
# - Load the excel file into a pandas data frame. Make sure that the endowment amounts and changes are float values and that the institution names only contain alphanumeric characters and whitespace. Drop the original versions of the columns.
# - Calculate the mean endowment for each institution sector, formatting the numbers with commas and only 2 digits after the decimal point. Which type of institution has the greatest mean endowment ? Is this suprising ?
